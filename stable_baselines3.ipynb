# %%
import gymnasium as gym

from stable_baselines3 import DQN

env = gym.make("CartPole-v1", render_mode="human")

model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000, log_interval=4)
model.save("dqn_cartpole")

del model # remove to demonstrate saving and loading

model = DQN.load("dqn_cartpole")

obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 25       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 31       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 172      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.491    |
# |    n_updates        | 17       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 35       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 254      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.472    |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 36       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 322      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.437    |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 38       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 382      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.415    |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 39       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 468      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 40       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 530      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.322    |
# |    n_updates        | 107      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 40       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 578      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 119      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 40       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 632      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.23     |
# |    n_updates        | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 41       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 678      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.199    |
# |    n_updates        | 144      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.311    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 41       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 725      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 41       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 766      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 41       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 809      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0961   |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 41       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 853      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.151    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 41       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 894      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 198      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.112    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 41       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 935      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.0785   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 41       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 970      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0785   |
# |    n_updates        | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 42       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1008     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0934   |
# |    n_updates        | 226      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 42       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1046     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0877   |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 42       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1086     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0475   |
# |    n_updates        | 246      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 42       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1126     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0691   |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 42       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0881   |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 42       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1203     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0596   |
# |    n_updates        | 275      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 42       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1244     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 285      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12
|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.62     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 42       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 2513     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00701  |
# |    n_updates        | 603      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.6      |
# |    ep_rew_mean      | 9.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 42       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 2550     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00474  |
# |    n_updates        | 612      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.59     |
# |    ep_rew_mean      | 9.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 42       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 2587     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00681  |
# |    n_updates        | 621      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.55     |
# |    ep_rew_mean      | 9.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 42       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 2624     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00408  |
# |    n_updates        | 630      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.52     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 42       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 2661     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0079   |
# |    n_updates        | 640      |
# ----------------------------------

# %%
import gymnasium as gym

from sb3_contrib import QRDQN

env = gym.make("CartPole-v1", render_mode="human")

policy_kwargs = dict(n_quantiles=50)
model = QRDQN("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(total_timesteps=10_000, log_interval=4)
model.save("qrdqn_cartpole")

del model # remove to demonstrate saving and loading

model = QRDQN.load("qrdqn_cartpole")

obs, _ = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    if terminated or truncated:
      obs, _ = env.reset()
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 27       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 74       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 31       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 135      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.8     |
# |    n_updates        | 8        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 33       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 171      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.8     |
# |    n_updates        | 17       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 35       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 208      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.4     |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 36       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 246      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.3     |
# |    n_updates        | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 37       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 282      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.2     |
# |    n_updates        | 45       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 37       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 320      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.1     |
# |    n_updates        | 54       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 38       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 357      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12       |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 38       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 396      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12       |
# |    n_updates        | 73       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 39       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 435      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 11.6     |
# |    n_updates        | 83       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 39       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 471      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 11.7     |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 40       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 512      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 11.4     |
# |    n_updates        | 102      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 40       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 549      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 11       |
# |    n_updates        | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 40       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 584      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 10.9     |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 40       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 622      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 10.5     |
# |    n_updates        | 130      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 40       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 660      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 10.7     |
# |    n_updates        | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 41       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 699      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 10.3     |
# |    n_updates        | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 41       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 737      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 10.5     |
# |    n_updates        | 159      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 41       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 775      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 9.99     |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 41       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 810      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 9.93     |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 41       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 848      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 9.87     |
# |    n_updates        | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 41       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 888      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 9.22     |
# |    n_updates        | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10
|
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.78     |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 43       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2055     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.43     |
# |    n_updates        | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 43       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2092     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.61     |
# |    n_updates        | 497      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.42     |
# |    ep_rew_mean      | 9.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 43       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 2131     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.27     |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 43       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2168     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.03     |
# |    n_updates        | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 43       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 2205     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.06     |
# |    n_updates        | 526      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 9.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 43       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 2243     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.26     |
# |    n_updates        | 535      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 43       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2278     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.71     |
# |    n_updates        | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | 9.4      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 43       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 2313     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.75     |
# |    n_updates        | 553      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 43       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 2350     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.99     |
# |    n_updates        | 562      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 43       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 2391     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.81     |
# |    n_updates        | 572      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 43       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 2428     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.48     |
# |    n_updates        | 581      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 9.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 43       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 2464     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.79     |
# |    n_updates        | 590      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 43       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 2499     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.46     |
# |    n_updates        | 599      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 9.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 43       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 2536     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.41     |
# |    n_updates        | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | 9.4      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 43       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 2574     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.36     |
# |    n_updates        | 618      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.35     |
# |    ep_rew_mean      | 9.35     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 43       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 2609     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.1      |
# |    n_updates        | 627      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.36     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 43       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 2647     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.04     |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.33     |
# |    ep_rew_mean      | 9.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 43       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 2683     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.27     |
# |    n_updates        | 645      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 43       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 2721     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.19     |
# |    n_updates        | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 43       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 2759     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.45     |
# |    n_updates        | 664      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.3      |
# |    ep_rew_mean      | 9.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 43       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 2798     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.96     |
# |    n_updates        | 674      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.28     |
# |    ep_rew_mean      | 9.28     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 43       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 2835     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.2      |
# |    n_updates        | 683      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.34     |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 43       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 2875     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.01     |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | 9.38     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 43       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 2916     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.26     |
# |    n_updates        | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.33     |
# |    ep_rew_mean      | 9.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 43       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 2953     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.35     |
# |    n_updates        | 713      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.36     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 43       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 2991     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.938    |
# |    n_updates        | 722      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | 9.38     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 43       |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 3030     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.02     |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.34     |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 43       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 3065     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.827    |
# |    n_updates        | 741      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.34     |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 43       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 3102     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.78     |
# |    n_updates        | 750      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.36     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 43       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 3141     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.801    |
# |    n_updates        | 760      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.37     |
# |    ep_rew_mean      | 9.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 43       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 3180     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.882    |
# |    n_updates        | 769      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 43       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 3219     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.947    |
# |    n_updates        | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 9.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 43       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 3260     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.7      |
# |    n_updates        | 789      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 9.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 43       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 3297     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.674    |
# |    n_updates        | 799      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 43       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 3335     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.648    |
# |    n_updates        | 808      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 9.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 43       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 3371     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.821    |
# |    n_updates        | 817      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 43       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 3408     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.817    |
# |    n_updates        | 826      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 43       |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 3443     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.773    |
# |    n_updates        | 835      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 43       |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.37     |
# |    ep_rew_mean      | 9.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 43       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 9050     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.153    |
# |    n_updates        | 2237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | 9.38     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 43       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 9088     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.152    |
# |    n_updates        | 2246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | 9.4      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 43       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 9126     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.175    |
# |    n_updates        | 2256     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 9.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 43       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 9166     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.152    |
# |    n_updates        | 2266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.48     |
# |    ep_rew_mean      | 9.48     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 43       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 9205     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.15     |
# |    n_updates        | 2276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46     |
# |    ep_rew_mean      | 9.46     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 43       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 9242     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.191    |
# |    n_updates        | 2285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 43       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 9279     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.151    |
# |    n_updates        | 2294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 43       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 9317     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.162    |
# |    n_updates        | 2304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 9.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 43       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 9351     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.158    |
# |    n_updates        | 2312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 43       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 9392     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.163    |
# |    n_updates        | 2322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 43       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 9429     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.146    |
# |    n_updates        | 2332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 43       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 9469     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.135    |
# |    n_updates        | 2342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 43       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 9506     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.154    |
# |    n_updates        | 2351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46     |
# |    ep_rew_mean      | 9.46     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 43       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 9546     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.141    |
# |    n_updates        | 2361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.51     |
# |    ep_rew_mean      | 9.51     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 43       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 9586     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.149    |
# |    n_updates        | 2371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.51     |
# |    ep_rew_mean      | 9.51     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 43       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 9623     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.135    |
# |    n_updates        | 2380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.51     |
# |    ep_rew_mean      | 9.51     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 43       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 9659     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.152    |
# |    n_updates        | 2389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 9.5      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 43       |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 9697     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.151    |
# |    n_updates        | 2399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.49     |
# |    ep_rew_mean      | 9.49     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 43       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 9733     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.142    |
# |    n_updates        | 2408     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       7 policy_kwargs = dict(n_quantiles=50)
#       8 model = QRDQN("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
# ----> 9 model.learn(total_timesteps=10_000, log_interval=4)
#      10 model.save("qrdqn_cartpole")
#      12 del model # remove to demonstrate saving and loading
#
# File e:\game_rl\venv\lib\site-packages\sb3_contrib\qrdqn\qrdqn.py:283, in QRDQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 def learn(
#     275     self: SelfQRDQN,
#     276     total_timesteps: int,
#    (...)
#     281     progress_bar: bool = False,
#     282 ) -> SelfQRDQN:
# --> 283     return super().learn(
#     284         total_timesteps=total_timesteps,
#     285         callback=callback,
#     286         log_interval=log_interval,
#     287         tb_log_name=tb_log_name,
#     288         reset_num_timesteps=reset_num_timesteps,
#     289         progress_bar=progress_bar,
#     290     )
#
# File e:\game_rl\venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:335, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     332 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     334 while self.num_timesteps < total_timesteps:
# --> 335     rollout = self.collect_rollouts(
#     336         self.env,
#     337         train_freq=self.train_freq,
#     338         action_noise=self.action_noise,
#     339         callback=callback,
#     340         learning_starts=self.learning_starts,
#     341         replay_buffer=self.replay_buffer,
#     342         log_interval=log_interval,
#     343     )
#     345     if not rollout.continue_training:
#     346         break
#
# File e:\game_rl\venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:567, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     564 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     566 # Rescale and perform action
# --> 567 new_obs, rewards, dones, infos = env.step(actions)
#     569 self.num_timesteps += env.num_envs
#     570 num_collected_steps += 1
#
# File e:\game_rl\venv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File e:\game_rl\venv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File e:\game_rl\venv\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File e:\game_rl\venv\lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File e:\game_rl\venv\lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File e:\game_rl\venv\lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File e:\game_rl\venv\lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File e:\game_rl\venv\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:223, in CartPoleEnv.step(self, action)
#     220     reward = -1.0 if self._sutton_barto_reward else 0.0
#     222 if self.render_mode == "human":
# --> 223     self.render()
#     225 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     226 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File e:\game_rl\venv\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:337, in CartPoleEnv.render(self)
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
# --> 337     self.clock.tick(self.metadata["render_fps"])
#     338     pygame.display.flip()
#     340 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
